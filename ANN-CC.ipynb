# %%
import pandas as pd
import numpy as np

data = pd.read_csv('data.csv')

# %%
import nltk
import string
import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
def text_lowercase(text):
    return text.lower()

def remove_punctuation(text):
    translator = str.maketrans('', '', string.punctuation)
    return text.translate(translator)
    
def remove_numbers(text):
    result = re.sub(r'\d+', '', text)
    return result

def remove_bracket(text):
    return re.sub('\[[^]]*\]', '', text)
    
def remove_special_characters(text):
    text = text.replace('-', ' ')  
    text = re.sub(r'[^a-zA-Z0-9\s]', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    text = re.sub(r"\n+", " ", text)
    return text

def remove_placeholders(text):
    return re.sub(r"\[\*\*.*?\*\*\]", "", text) 

def remove_stopwords(text):
    stop_words = set(stopwords.words("english"))
    word_tokens = word_tokenize(text)
    word_tokens = [word for word in word_tokens if word not in stop_words]
    text = ' '.join(word_tokens) # rejoin tokens into a single string
    return text

# %%
def clean_text(text):
    text = text_lowercase(text)
    text = remove_placeholders(text)
    text = remove_bracket(text)
    text = remove_numbers(text)
    text = remove_special_characters(text)
    text = remove_punctuation(text)
    text = remove_stopwords(text) 
    return text

# %%
data['TEXT'] = data['TEXT'].apply(clean_text)

# %%
def multi_label_accuracy(y_true, y_pred):
    """
    Calculate multi-label accuracy.
    
    Args:
        y_true (pd.DataFrame or np.ndarray): True binary labels.
        y_pred (pd.DataFrame or np.ndarray): Predicted binary labels.
        
    Returns:
        float: Multi-label accuracy.
    """
    # Convert DataFrame to NumPy array if needed
    if isinstance(y_true, pd.DataFrame):
        y_true = y_true.values
    if isinstance(y_pred, pd.DataFrame):
        y_pred = y_pred.values
    
    n_samples = y_true.shape[0]
    accuracy_sum = 0.0
    
    for i in range(n_samples):
        true_set = set(np.where(y_true[i])[0])
        pred_set = set(np.where(y_pred[i])[0])
        
        intersection = len(true_set & pred_set)
        union = len(true_set | pred_set)
        
        if union == 0:
            accuracy_sum += 1.0
        else:
            accuracy_sum += intersection / union
    
    return accuracy_sum / n_samples

# %%
X = data['TEXT']
y = data.iloc[:, 3:]

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, shuffle=True, random_state=42)

X_train = X_train.reset_index(drop=True)
X_test = X_test.reset_index(drop=True)
y_train = y_train.reset_index(drop=True)
y_test = y_test.reset_index(drop=True)

print("Number of Observations in the Data set:" , X.values.shape[0]) 
print("Number of Observations in Train set:", X_train.shape[0])
print("Number of Observations in Test set:" , X_test.shape[0])
# Out:
# Number of Observations in the Data set: 48335
# Number of Observations in Train set: 33834
# Number of Observations in Test set: 14501

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

vectorizer = TfidfVectorizer(max_features=10000)

X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

# %%
X_train_dense = X_train_vectorized.toarray()
X_test_dense = X_test_vectorized.toarray()

# %%
X_train_dense.shape
# Out:
# (33834, 10000)

# %% [markdown]
# ## ANN Chain Model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
from time import time

# %%
def create_c1node(X_feed,y_now):
    '''
    C1 node Architecture:
    attribute:512:256:1 [saperate for each class]
    loss: Binary crossentropy
    '''
    model = Sequential()
    model.add(Dense(512,activation='relu',input_shape=(X_feed.shape[1],),kernel_initializer='glorot_uniform',name='first'))
    model.add(Dropout(0.4))
    model.add(Dense(256,activation='relu',kernel_initializer='glorot_uniform',name='nretrain1'))
    model.add(Dropout(0.4))
    model.add(Dense(128,activation='relu',kernel_initializer='glorot_uniform',name='nretrain2'))
    model.add(Dropout(0.4))
    model.add(Dense(64,activation='relu',kernel_initializer='glorot_uniform',name='last'))
    model.add(Dropout(0.4))    
    model.add(Dense(y_now.shape[1],activation='sigmoid',kernel_initializer='glorot_uniform',name='output'))
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['acc'])
    return model

# %%
#Model chain
chain = []

#Training
X_feed = X_train_dense.copy()
t1 = time()
for i in range(y_train.shape[1]):
    print("Training chain node ", i)
    y_now = y_train.iloc[:, [i,]].copy()
    print("Shapes:\n X = {} \n Y = {}".format(X_feed.shape, y_now.shape))

    node = create_c1node(X_feed, y_now)
    node.fit(X_feed ,y_now, epochs=8, batch_size=64)
    print("Training of node {} complete\n\n".format(i))  
    #Adding node to chain 
    chain.append(node)
    
    # Now append y_now to X_feed
    X_feed = np.append(X_feed, y_now, axis=1)

t2 = time()

print("Time taken: ",(t2-t1))
# Out:
# Training chain node  0
# Shapes:
#  X = (33834, 10000)
#  Y = (33834, 1)
# C:\Users\UserX\anaconda3\Lib\site-packages\keras\src\layers\core\dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 45s 75ms/step - acc: 0.8443 - loss: 0.3945
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.8820 - loss: 0.2706
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 73ms/step - acc: 0.9041 - loss: 0.2246
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9274 - loss: 0.1768
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - acc: 0.9532 - loss: 0.1199
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 73ms/step - acc: 0.9718 - loss: 0.0776
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9796 - loss: 0.0577
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9859 - loss: 0.0402
# Training of node 0 complete
#
#
# Training chain node  1
# Shapes:
#  X = (33834, 10001)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 77ms/step - acc: 0.7706 - loss: 0.4796
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9018 - loss: 0.2650
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9290 - loss: 0.2005
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 73ms/step - acc: 0.9467 - loss: 0.1515
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9697 - loss: 0.0953
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 73ms/step - acc: 0.9771 - loss: 0.0675
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 73ms/step - acc: 0.9840 - loss: 0.0497
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 73ms/step - acc: 0.9877 - loss: 0.0374
# Training of node 1 complete
#
#
# Training chain node  2
# Shapes:
#  X = (33834, 10002)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 46s 75ms/step - acc: 0.8577 - loss: 0.3904
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.8704 - loss: 0.2943
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 73ms/step - acc: 0.8912 - loss: 0.2578
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 38s 73ms/step - acc: 0.9230 - loss: 0.1944
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9526 - loss: 0.1220
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9721 - loss: 0.0789
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9800 - loss: 0.0529
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 73ms/step - acc: 0.9855 - loss: 0.0415
# Training of node 2 complete
#
#
# Training chain node  3
# Shapes:
#  X = (33834, 10003)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 75ms/step - acc: 0.8803 - loss: 0.3261
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9252 - loss: 0.1869
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9429 - loss: 0.1472
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9609 - loss: 0.1051
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9764 - loss: 0.0660
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9861 - loss: 0.0410
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9895 - loss: 0.0295
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9925 - loss: 0.0245
# Training of node 3 complete
#
#
# Training chain node  4
# Shapes:
#  X = (33834, 10004)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 75ms/step - acc: 0.6882 - loss: 0.5513
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.8294 - loss: 0.3839
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.8800 - loss: 0.2898
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9241 - loss: 0.1932
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9563 - loss: 0.1186
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9716 - loss: 0.0760
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9801 - loss: 0.0535
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 39s 74ms/step - acc: 0.9857 - loss: 0.0427
# Training of node 4 complete
#
#
# Training chain node  5
# Shapes:
#  X = (33834, 10005)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 45s 76ms/step - acc: 0.8062 - loss: 0.4189
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - acc: 0.9015 - loss: 0.2508
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.9310 - loss: 0.1817
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9564 - loss: 0.1196
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9724 - loss: 0.0739
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9835 - loss: 0.0481
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9857 - loss: 0.0384
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9928 - loss: 0.0225
# Training of node 5 complete
#
#
# Training chain node  6
# Shapes:
#  X = (33834, 10006)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 76ms/step - acc: 0.8139 - loss: 0.4098
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9056 - loss: 0.2370
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9249 - loss: 0.1847
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9499 - loss: 0.1213
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - acc: 0.9726 - loss: 0.0751
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9823 - loss: 0.0509
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9861 - loss: 0.0362
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 48s 90ms/step - acc: 0.9903 - loss: 0.0310
# Training of node 6 complete
#
#
# Training chain node  7
# Shapes:
#  X = (33834, 10007)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - acc: 0.8561 - loss: 0.3880
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9042 - loss: 0.2516
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 75ms/step - acc: 0.9277 - loss: 0.1945
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9475 - loss: 0.1454
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.9680 - loss: 0.0892
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - acc: 0.9807 - loss: 0.0561
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9854 - loss: 0.0420
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - acc: 0.9892 - loss: 0.0322
# Training of node 7 complete
#
#
# Training chain node  8
# Shapes:
#  X = (33834, 10008)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 46s 78ms/step - acc: 0.9086 - loss: 0.2323
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9698 - loss: 0.0881
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 40s 76ms/step - acc: 0.9803 - loss: 0.0539
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - acc: 0.9918 - loss: 0.0253
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - acc: 0.9937 - loss: 0.0192
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9966 - loss: 0.0104
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - acc: 0.9967 - loss: 0.0096
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9975 - loss: 0.0076
# Training of node 8 complete
#
#
# Training chain node  9
# Shapes:
#  X = (33834, 10009)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 46s 79ms/step - acc: 0.8238 - loss: 0.4256
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.8726 - loss: 0.3001
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.9010 - loss: 0.2414
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - acc: 0.9296 - loss: 0.1767
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9552 - loss: 0.1169
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9742 - loss: 0.0746
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9795 - loss: 0.0577
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9849 - loss: 0.0414
# Training of node 9 complete
#
#
# Training chain node  10
# Shapes:
#  X = (33834, 10010)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 46s 78ms/step - acc: 0.7487 - loss: 0.5250
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.8020 - loss: 0.4258
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.8378 - loss: 0.3632
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.8859 - loss: 0.2754
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9305 - loss: 0.1769
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9536 - loss: 0.1228
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 45s 84ms/step - acc: 0.9685 - loss: 0.0847
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 45s 85ms/step - acc: 0.9755 - loss: 0.0680
# Training of node 10 complete
#
#
# Training chain node  11
# Shapes:
#  X = (33834, 10011)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 46s 78ms/step - acc: 0.8668 - loss: 0.3818
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 78ms/step - acc: 0.8957 - loss: 0.2506
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9220 - loss: 0.1902
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - acc: 0.9469 - loss: 0.1358
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9687 - loss: 0.0875
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9792 - loss: 0.0568
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9861 - loss: 0.0397
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9901 - loss: 0.0322
# Training of node 11 complete
#
#
# Training chain node  12
# Shapes:
#  X = (33834, 10012)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 45s 78ms/step - acc: 0.7951 - loss: 0.4390
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.8926 - loss: 0.2737
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 47s 90ms/step - acc: 0.9213 - loss: 0.2070
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - acc: 0.9464 - loss: 0.1446
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9671 - loss: 0.0940
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9775 - loss: 0.0657
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9821 - loss: 0.0500
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9868 - loss: 0.0382
# Training of node 12 complete
#
#
# Training chain node  13
# Shapes:
#  X = (33834, 10013)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 49s 78ms/step - acc: 0.7997 - loss: 0.4356
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - acc: 0.9344 - loss: 0.1919
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.9559 - loss: 0.1291
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 80ms/step - acc: 0.9686 - loss: 0.0884
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9816 - loss: 0.0556
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - acc: 0.9854 - loss: 0.0437
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9893 - loss: 0.0314
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - acc: 0.9916 - loss: 0.0248
# Training of node 13 complete
#
#
# Training chain node  14
# Shapes:
#  X = (33834, 10014)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 46s 77ms/step - acc: 0.8785 - loss: 0.2960
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 41s 77ms/step - acc: 0.9338 - loss: 0.1612
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9528 - loss: 0.1221
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9719 - loss: 0.0757
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9830 - loss: 0.0473
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9882 - loss: 0.0318
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9935 - loss: 0.0181
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 80ms/step - acc: 0.9949 - loss: 0.0167
# Training of node 14 complete
#
#
# Training chain node  15
# Shapes:
#  X = (33834, 10015)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 47s 79ms/step - acc: 0.9726 - loss: 0.0663
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9987 - loss: 0.0050
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9994 - loss: 0.0032
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9997 - loss: 0.0015
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9998 - loss: 6.7035e-04
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 80ms/step - acc: 1.0000 - loss: 9.5629e-05
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 80ms/step - acc: 0.9998 - loss: 7.4120e-04
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 80ms/step - acc: 1.0000 - loss: 8.7298e-05
# Training of node 15 complete
#
#
# Training chain node  16
# Shapes:
#  X = (33834, 10016)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 45s 77ms/step - acc: 0.8498 - loss: 0.4141
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.8870 - loss: 0.2836
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9275 - loss: 0.1914
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - acc: 0.9505 - loss: 0.1363
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9706 - loss: 0.0839
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9791 - loss: 0.0612
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9850 - loss: 0.0451
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9882 - loss: 0.0347
# Training of node 16 complete
#
#
# Training chain node  17
# Shapes:
#  X = (33834, 10017)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 45s 77ms/step - acc: 0.7390 - loss: 0.5172
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.8300 - loss: 0.3697
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 80ms/step - acc: 0.8865 - loss: 0.2712
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.9221 - loss: 0.1942
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 79ms/step - acc: 0.9490 - loss: 0.1303
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 83ms/step - acc: 0.9675 - loss: 0.0889
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9745 - loss: 0.0688
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9806 - loss: 0.0524
# Training of node 17 complete
#
#
# Training chain node  18
# Shapes:
#  X = (33834, 10018)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 46s 78ms/step - acc: 0.7778 - loss: 0.4647
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.8626 - loss: 0.3262
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.8979 - loss: 0.2528
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9290 - loss: 0.1848
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9552 - loss: 0.1206
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9723 - loss: 0.0747
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 82ms/step - acc: 0.9798 - loss: 0.0535
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.9853 - loss: 0.0426
# Training of node 18 complete
#
#
# Training chain node  19
# Shapes:
#  X = (33834, 10019)
#  Y = (33834, 1)
# Epoch 1/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 47s 78ms/step - acc: 0.7255 - loss: 0.5408
# Epoch 2/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 43s 81ms/step - acc: 0.8003 - loss: 0.4452
# Epoch 3/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 44s 82ms/step - acc: 0.8414 - loss: 0.3691
# Epoch 4/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.8864 - loss: 0.2750
# Epoch 5/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9304 - loss: 0.1865
# Epoch 6/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9566 - loss: 0.1163
# Epoch 7/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9678 - loss: 0.0865
# Epoch 8/8
# 529/529 ━━━━━━━━━━━━━━━━━━━━ 42s 80ms/step - acc: 0.9780 - loss: 0.0635
# Training of node 19 complete
#
#
# Time taken:  7147.267694234848

# %%
y_pred = []

X_feed = X_test_dense.copy()

i = 0
for node in chain:
    print("Getting op from chain node ",i)
    node_name = "Node" + str(i)
    print("Shapes:\n X = {}".format(X_feed.shape))
    output = node.predict(X_feed)
    output = output.round().astype(int)
    y_pred.append(output)
    X_feed = np.append(X_feed, output, axis=1)
    i+=1
# Out:
# Getting op from chain node  0
# Shapes:
#  X = (14501, 10000)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 7s 10ms/step
# Getting op from chain node  1
# Shapes:
#  X = (14501, 10001)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  2
# Shapes:
#  X = (14501, 10002)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step
# Getting op from chain node  3
# Shapes:
#  X = (14501, 10003)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step
# Getting op from chain node  4
# Shapes:
#  X = (14501, 10004)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  5
# Shapes:
#  X = (14501, 10005)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step
# Getting op from chain node  6
# Shapes:
#  X = (14501, 10006)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 10ms/step
# Getting op from chain node  7
# Shapes:
#  X = (14501, 10007)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 7s 9ms/step
# Getting op from chain node  8
# Shapes:
#  X = (14501, 10008)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step
# Getting op from chain node  9
# Shapes:
#  X = (14501, 10009)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  10
# Shapes:
#  X = (14501, 10010)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  11
# Shapes:
#  X = (14501, 10011)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  12
# Shapes:
#  X = (14501, 10012)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  13
# Shapes:
#  X = (14501, 10013)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  14
# Shapes:
#  X = (14501, 10014)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  15
# Shapes:
#  X = (14501, 10015)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  16
# Shapes:
#  X = (14501, 10016)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  17
# Shapes:
#  X = (14501, 10017)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  18
# Shapes:
#  X = (14501, 10018)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step
# Getting op from chain node  19
# Shapes:
#  X = (14501, 10019)
# 454/454 ━━━━━━━━━━━━━━━━━━━━ 4s 9ms/step

# %%
predictions = np.array([0])
for i in y_pred:
    x = np.array(i)
    if predictions.shape == (1,):
        predictions = x
    else:
        predictions = np.append(predictions, x, axis=1)

# %%
from sklearn.metrics import hamming_loss, log_loss, f1_score, accuracy_score, jaccard_score, classification_report

print("Accuracy = ", accuracy_score(y_test, predictions))
print("\nJaccard Score (micro)= ", jaccard_score(y_test, predictions, average='micro'))
print("\nJaccard Score (macro)= ", jaccard_score(y_test, predictions, average='macro'))
print("\nHamming loss = ", hamming_loss(y_test, predictions))
#print("Log loss = ", log_loss(y_test, predictions))
print("\nF1 score (micro) = ", f1_score(y_test, predictions, average='micro'))
print("\nF1 score (macro) = ", f1_score(y_test, predictions, average='macro'))

ann_cc_ml_accuracy = multi_label_accuracy(y_test, predictions)
print(f'Multi Label Accuracy: {ann_cc_ml_accuracy:.4f}')
# Out:
# Accuracy =  0.1230259982070202
#
# Jaccard Score (micro)=  0.49687713353731006
#
# Jaccard Score (macro)=  0.49505745145788216
#
# Hamming loss =  0.137211226811944
#
# F1 score (micro) =  0.663884994172002
#
# F1 score (macro) =  0.6469201625002781
# Multi Label Accuracy: 0.5151
